# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 878.7/878.7 kB 36.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
from IPython.display import Image, display
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Ufl04ATrDjaUKYZdsr6y")
project = rf.workspace("30201220").project("beverage-containers-3atxb-vqovx-1ubgt")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Beverage-Containers-1 in yolov11:: 100%|██████████| 31226/31226 [00:15<00:00, 1995.53it/s]

# %%
# !yolo task=detect mode=train model=yolo11s.pt data=/content/Beverage-Containers-1/data.yaml epochs=20 imgsz=640 batch=16 plots=True project=/content/drive/MyDrive/yolov11/train name=exp
# Out:
# ...
# 100% 18.4M/18.4M [00:00<00:00, 157MB/s]
# Ultralytics 8.3.25 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=val model=/content/drive/MyDrive/yolov11/train/exp/weights/best.pt data=/content/Beverage-Containers-1/data.yaml imgsz=640 project=/content/drive/MyDrive/yolov11/val name=exp
# Out:
# Ultralytics 8.3.25 🚀 Python-3.10.12 torch-2.5.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLO11s summary (fused): 238 layers, 9,416,283 parameters, 0 gradients, 21.3 GFLOPs
# ...
# 100% 755k/755k [00:00<00:00, 41.5MB/s]
# val: Scanning /content/Beverage-Containers-1/valid/labels... 1303 images, 0 backgrounds, 0 corrupt: 100% 1303/1303 [00:00<00:00, 1732.26it/s]
# val: New cache created: /content/Beverage-Containers-1/valid/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 82/82 [13:50<00:00, 10.12s/it]
#                    all       1303       1924      0.928      0.906      0.958      0.878
#           bottle-glass        193        297      0.961      0.913      0.963      0.875
#         bottle-plastic        176        224      0.917      0.893      0.955      0.858
#         cup-disposable        126        201       0.93      0.853      0.947      0.877
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/yolov11/train/exp/weights/best.pt data=/content/Beverage-Containers-1/data.yaml conf=0.25 imgsz=640 source=/content/Beverage-Containers-1/test/images imgsz=640 project=/content/drive/MyDrive/yolov11/test name=exp
# Out:
# Ultralytics 8.3.25 🚀 Python-3.10.12 torch-2.5.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLO11s summary (fused): 238 layers, 9,416,283 parameters, 0 gradients, 21.3 GFLOPs
#
# image 1/653 /content/Beverage-Containers-1/test/images/000000002106_jpg.rf.09446312b2d89958db59bb099f8787ea.jpg: 640x448 2 glass-wines, 455.1ms
# image 2/653 /content/Beverage-Containers-1/test/images/000000008711_jpg.rf.02e611af1d5b34f1056b1a03aa53e341.jpg: 480x640 1 cup-disposable, 454.4ms
# image 3/653 /content/Beverage-Containers-1/test/images/000000017210_jpg.rf.19cafc954ec135f05045adb5e6c5f6a1.jpg: 640x640 1 cup-disposable, 552.5ms
# image 4/653 /content/Beverage-Containers-1/test/images/000000067657_jpg.rf.1d55c855eec39c3ed84b6f28143866e1.jpg: 480x640 1 bottle-glass, 2 glass-wines, 389.9ms
# image 5/653 /content/Beverage-Containers-1/test/images/000000081944_jpg.rf.a511974d11b696d95f3e6af3ea78aa9a.jpg: 640x448 1 cup-handle, 373.1ms
# ...

# %%
# import glob
# i=0
# for imageNet in glob.glob('/content/Beverage-Containers-1/detect/exp/*.jpg'):
#   print('\n')
#   if i%5 ==0:
#     display(Image(filename=imageNet))
#     i+=1
