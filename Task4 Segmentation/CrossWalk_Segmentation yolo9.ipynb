# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Ufl04ATrDjaUKYZdsr6y")
project = rf.workspace("image-process-1mqey").project("crosswalk-ta")
version = project.version(8)
dataset = version.download("yolov9")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to crosswalk-TA-8 in yolov9:: 100%|██████████| 2212/2212 [00:00<00:00, 4155.37it/s]

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 896.9/896.9 kB 23.0 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.39 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.7/112.6 GB disk)

# %%
# !yolo task= segment mode= train data= /content/crosswalk-TA-8/data.yaml model= /content/runs/segment/train2/weights/best.pt epochs= 10 batch= 4 imgsz= 640
# Out:
# Ultralytics 8.3.39 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task= segment mode= train data= /content/crosswalk-TA-8/data.yaml model= /content/runs/segment/train3/weights/best.pt epochs= 20 batch= 4 imgsz= 640
# Out:
# Ultralytics 8.3.39 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task= segment mode= train data= /content/crosswalk-TA-8/data.yaml model= /content/runs/segment/train4/weights/best.pt epochs= 20 batch= 4 imgsz= 640

# %% [markdown]
# ## predict

# %%
# !yolo task= segment  mode= predict model= /content/runs/segment/train4/weights/best.pt batch= 4 imgsz= 640 conf= 0.5 source= /content/crosswalk-TA-8/test/images
# Out:
# Ultralytics 8.3.39 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv9e-seg summary (fused): 714 layers, 59,682,451 parameters, 0 gradients, 244.4 GFLOPs
#
# image 1/220 /content/crosswalk-TA-8/test/images/100_jpg.rf.94d9d8e9e6f098e8ff229f703c53a8ba.jpg: 640x640 1 crosswalk, 80.2ms
# image 2/220 /content/crosswalk-TA-8/test/images/100_jpg.rf.9ba4662a716204ef7247714b6435157a.jpg: 640x640 1 crosswalk, 80.2ms
# image 3/220 /content/crosswalk-TA-8/test/images/103_jpg.rf.8d2b13b9a8f525d8a2570cf8fb989855.jpg: 640x640 1 crosswalk, 80.2ms
# image 4/220 /content/crosswalk-TA-8/test/images/104_jpg.rf.831a2445f627ff2718a3999be63178c0.jpg: 640x640 1 crosswalk, 80.2ms
# image 5/220 /content/crosswalk-TA-8/test/images/104_jpg.rf.8ac208f7881149b5382f8e398ed45c6b.jpg: 640x640 1 crosswalk, 69.9ms
# image 6/220 /content/crosswalk-TA-8/test/images/108_jpg.rf.bbdef1e1be151459a4738bf1ea42d702.jpg: 640x640 1 crosswalk, 69.9ms
# ...

# %%
import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/runs/segment/predict/*.jpg')[:5]:
  print('\n')
  display(Image(filename= imageName))
